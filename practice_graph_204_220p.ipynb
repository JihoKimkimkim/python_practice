# %% [markdown]
# <a href="https://colab.research.google.com/github/JihoKimkimkim/python_practice/blob/main/practice_graph_204_220p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# '쉽게 배우는 파이썬 데이터 분석, 김영우, 2022'
#204-220p
import pandas as pd
import numpy as np
import seaborn as sns
mpg = pd.read_csv('/content/drive/MyDrive/pything/mpg.csv')

# %%
#Q1. x축 cry y축 hwy 산점도
sns.scatterplot(data = mpg, x = 'cty', y ='hwy')
# Out:
# <Axes: xlabel='cty', ylabel='hwy'>

# %%
#Q2. midwest이용, x축 poptatal(50만명이하) y축 popasian(1만명이하) 산점도
midwest = pd.read_csv('/content/drive/MyDrive/pything/midwest.csv')
sns.scatterplot(data = midwest, x = 'poptotal', y = 'popasian')\
.set(xlim = [0, 500800], ylim = [0, 10000])
# Out:
# [(0.0, 500800.0), (0.0, 10000.0)]

# %%
#211p 막대 그래프
#Q1. ’suv’차종 대상 cty 평균이 가장 높은 회사 다섯곳 막대그래프(연비순)
mpg = pd.read_csv('/content/drive/MyDrive/pything/mpg_2.csv')
df = mpg.query('category == "suv"')\
        .groupby('manufacturer', as_index = False)\
        .agg(mean_cty = ('cty', 'mean'))\
        .sort_values('mean_cty', ascending = False)\
        .head()
df
# Out:
#   manufacturer   mean_cty
# 8       subaru  18.833333
# 9       toyota  14.375000
# 7       nissan  13.750000
# 3         jeep  13.500000
# 6      mercury  13.250000

# %%
sns.barplot(data = df, x = 'manufacturer', y = 'mean_cty')
# Out:
# <Axes: xlabel='manufacturer', ylabel='mean_cty'>

# %%
#Q2.sns.barplot()을 이용해 자동차 종류별 빈도 막대그래프(높은 순)
df_mpg = mpg.groupby('category', as_index = False)\
            .agg(n = ('category', 'count'))\
            .sort_values('n', ascending = False)
df_mpg
# Out:
#      category   n
# 6         suv  62
# 1     compact  47
# 2     midsize  41
# 5  subcompact  35
# 4      pickup  33
# 3     minivan  11
# 0     2seater   5

# %%
sns.barplot (data = df_mpg, x = 'category', y = 'n')
# Out:
# <Axes: xlabel='category', ylabel='n'>

# %%
#217p 선 그래프_시계열 그래프
#Q1. 연도별 psavert(개인 저축률) 시계열 그래프
economics = pd.read_csv('/content/drive/MyDrive/pything/economics.csv')
economics['date2'] = pd.to_datetime(economics['date'])
economics['year'] = economics['date2'].dt.year
sns.lineplot (data = economics, x = 'year', y = 'psavert', errorbar = None)
# Out:
# <Axes: xlabel='year', ylabel='psavert'>

# %%
#Q2. 2014 월별 pasvert 시계열 그래프
economics['month'] = economics ['date2'].dt.month
#2014년 수출
df_2014 = economics.query('year == 2014')
#선 그래프 만들기
sns.lineplot(data = df_2014, x = 'month', y = 'psavert', errorbar = None)
# Out:
# <Axes: xlabel='month', ylabel='psavert'>

# %%
#220p 상자 그래프
#Q1. category ‘compact’ ‘subcompact’ ‘suv’ cty(도시 연비) 상자 그림
mpg_2 = pd.read_csv('/content/drive/MyDrive/pything/mpg_2.csv')
df = mpg_2.query('category in ["compact", "subcompact", "suv"]')
sns.boxplot (data = df, x = 'category', y = 'cty')
# Out:
# <Axes: xlabel='category', ylabel='cty'>
